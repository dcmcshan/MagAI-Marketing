# %% [markdown]
# # Notebook 7: MCP & real signals (template)
#
# **Goal:** Connect **one** approved MCP tool or export to a variable in your personal influence model — or document **synthetic** data and the bridge to reality.
#
# Read `docs/MCP_MARKETING.md` before running anything against live accounts.

# %% [markdown]
# ## Data card (fill in)
#
# | Field | Your notes |
# | --- | --- |
# | Source |  |
# | Scope (read/write) |  |
# | Freshness / lag |  |
# | Maps to model variable |  |
# | What would falsify your model? |  |

# %%
# Placeholder: ingest a CSV export or call an MCP-backed helper your faculty provides.
# import pandas as pd
# df = pd.read_csv("your_export.csv")
# df.head()

# %% [markdown]
# ## One paragraph
#
# If the signal above disagreed with your simulation, **which rule would you change first** — and why?

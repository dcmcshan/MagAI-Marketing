# %% [markdown]
# # Notebook 8: Defense prep & one-page report
#
# Use this notebook to finalize **lineage** and **talk track** — not new simulation logic.

# %% [markdown]
# ## Notebook index (paths in your repo / iNQspace)
#
# 1.
# 2.
# 3.
#
# ## Revision log
#
# | Date | What changed | Why |
# | --- | --- | --- |
# | | | |

# %% [markdown]
# ## One-page influence report (final)
#
# **Ontology:**
#
# **Baseline / optimized / stress** (one line each):
#
# **Top 3 sensitivities:**
#
# **Ethical line I will not cross:**
#
# **MCP scope (or synthetic-only justification):**

# %%
# Optional: re-run your integrated simulation from prior notebooks for a fresh figure.
pass
